# %%
import pandas as pd

md = pd.read_csv('../Metadata/metadata_final_22102024.tsv', sep='\t')

md["subject_ID_x_group"] = (
    md["subject_ID"].astype(str).str.strip() + "_" +
    md["group"].astype(str).str.strip()
)

md.to_csv(
    '../Metadata/metadata_final_22102024.tsv',
    sep='\t',
    index=False
)

# %%
md['subject_ID'].unique()
# Out:
# array(['PP_308', 'PP_310', 'PP_305', 'PP_306', 'PP_313', 'PP_317',
#        'PP_304', 'PP_2', 'PP_314', 'PP_3', 'PP_17', 'PP_318', 'PP_7',
#        'PP_4', 'PP_1', 'PP_14', 'PP_319', 'PP_6', 'PP_11', 'PP_18'],
#       dtype=object)

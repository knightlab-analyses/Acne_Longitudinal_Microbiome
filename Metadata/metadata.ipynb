# %%
import pandas as pd

md = pd.read_csv('../Metadata/metadata_final_22102024.tsv', sep='\t')

md["subject_ID_x_group"] = (
    md["subject_ID"].astype(str).str.strip() + "_" +
    md["group"].astype(str).str.strip()
)

md.to_csv(
    '../Metadata/metadata_final_22102024.tsv',
    sep='\t',
    index=False
)

# %%
md
# Out:
#               SampleID c_zone  \
# 0    LAMI.RD308.D16.C1     C1
# 1    LAMI.RD310.D21.C1     C1
# 2    LAMI.RD305.D21.C3     C3
# 3    LAMI.RD306.D18.C2     C2
# 4     LAMI.RD306.D7.C2     C2
# ..                 ...    ...
# 261  LAMI.RD317.D21.C1     C1
# 262   LAMI.RD001.D0.C1     C1
# 263  LAMI.RD014.D14.C2     C2
# 264   LAMI.RD314.D0.C1     C1
# 265  LAMI.RD001.D14.C2     C2
#
#     visual_assessment_in_vivo_number_of_non_inflammatory_lesions_face  \
# 0                                       not applicable
# 1                                                   72
# 2                                                   69
# 3                                       not applicable
# 4                                                   90
# ..                                                 ...
# 261                                                 77
# 262                                     not applicable
# 263                                     not applicable
# 264                                                 55
# 265                                     not applicable
#
#              zone sample_type planned_study_day_of_visit  \
# 0        Lesional        skin                     Day 16
# 1        Lesional        skin                     Day 21
# 2    Non-lesional        skin                     Day 21
# 3        Lesional        skin                     Day 18
# 4        Lesional        skin                      Day 7
# ..            ...         ...                        ...
# 261      Lesional        skin                     Day 21
# 262  Non-lesional        skin                      Day 0
# 263  Non-lesional        skin                     Day 14
# 264      Lesional        skin                      Day 0
# 265  Non-lesional        skin                     Day 14
#
#     visual_assessment_in_vivo_number_of_inflammatory_lesions_face  day  \
# 0                                       not applicable              16
# 1                                                   36              21
# 2                                                   26              21
# 3                                       not applicable              18
# 4                                                   13               7
# ..                                                 ...             ...
# 261                                                 19              21
# 262                                     not applicable               0
# 263                                     not applicable              14
# 264                                                 31               0
# 265                                     not applicable              14
#
#      subject_randomization_number  \
# 0                             308
# 1                             310
# 2                             305
# 3                             306
# 4                             306
# ..                            ...
# 261                           317
# 262                             1
# 263                            14
# 264                           314
# 265                             1
#
#     visual_assessment_in_vivo_number_of_non_inflammatory_lesions_cheek_right  \
# 0                                       not applicable
# 1                                                   17
# 2                                                   25
# 3                                       not applicable
# 4                                                   23
# ..                                                 ...
# 261                                                 20
# 262                                     not applicable
# 263                                     not applicable
# 264                                                 16
# 265                                     not applicable
#
#      ...   cohort subject_randomization_id    class subject_ID subject_ID_CC  \
# 0    ...     acne                    RD308     acne     PP_308      PP_308C1
# 1    ...     acne                    RD310     acne     PP_310      PP_310C1
# 2    ...     acne                    RD305  healthy     PP_305      PP_305C3
# 3    ...     acne                    RD306     acne     PP_306      PP_306C2
# 4    ...     acne                    RD306     acne     PP_306      PP_306C2
# ..   ...      ...                      ...      ...        ...           ...
# 261  ...     acne                    RD317     acne     PP_317      PP_317C1
# 262  ...  control                    RD001  healthy       PP_1        PP_1C1
# 263  ...  control                    RD014  healthy      PP_14       PP_14C2
# 264  ...     acne                    RD314     acne     PP_314      PP_314C1
# 265  ...  control                    RD001  healthy       PP_1        PP_1C2
#
#              zone_CC    group severity_level   severity_group  \
# 0        Lesional_C1   Acne_L       moderate  moderate Acne_L
# 1        Lesional_C1   Acne_L       moderate  moderate Acne_L
# 2    Non-lesional_C3  Acne_NL         absent   absent Acne_NL
# 3        Lesional_C2   Acne_L            low       low Acne_L
# 4        Lesional_C2   Acne_L       moderate  moderate Acne_L
# ..               ...      ...            ...              ...
# 261      Lesional_C1   Acne_L            low       low Acne_L
# 262  Non-lesional_C1  Healthy         absent   absent Healthy
# 263  Non-lesional_C2  Healthy         absent   absent Healthy
# 264      Lesional_C1   Acne_L            low       low Acne_L
# 265  Non-lesional_C2  Healthy         absent   absent Healthy
#
#     subject_ID_x_group
# 0        PP_308_Acne_L
# 1        PP_310_Acne_L
# 2       PP_305_Acne_NL
# 3        PP_306_Acne_L
# 4        PP_306_Acne_L
# ..                 ...
# 261      PP_317_Acne_L
# 262       PP_1_Healthy
# 263      PP_14_Healthy
# 264      PP_314_Acne_L
# 265       PP_1_Healthy
#
# [266 rows x 36 columns]

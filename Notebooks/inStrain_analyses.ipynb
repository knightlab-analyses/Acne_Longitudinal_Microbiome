# %% [markdown]
# # Strain-level analyses from WGS dataset
# ## inStrain nucleotide diversity and dN/dS analysis
#
# Date created: 11/3/2024
#
# Notebook authors: Yang Chen
#
# Data analysis by: Yang Chen
#
# This notebook plots the following:
#
# - Nucleotide diversity results from inStrain based on MAGs grouped at species level
# - Nucleotide diversity results from inStrain based on MAGs grouped by _C. acnes_ MLST strain type
# - dN/dS analysis (TBD)

# %%
# Import Python packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import ScalarFormatter
from scipy.stats import mannwhitneyu
import itertools
from scipy.stats import kruskal
from matplotlib.ticker import ScalarFormatter
import matplotlib.colors as mcolors
import statannot

# %%
# Read in inStrain merged genome info file
path = '../Data/metaG/inStrain_files/inStrain_merged_genome_info.tsv'
df = pd.read_csv(path, sep='\t')
df
# Out:
#                                                  genome   coverage   breadth  \
# 0        LAMI_RD304_D0_C1_S1_L005__METABAT2__E.1__bin.1   4.962335  0.951691
# 1        LAMI_RD304_D0_C1_S1_L005__METABAT2__P.1__bin.2  28.946285  0.997830
# 2     LAMI_RD304_D0_C3_S2_L005__MAXBIN2-107__P.1__bi...  27.889266  0.997830
# 3        LAMI_RD304_D0_C3_S2_L005__METABAT2__E.1__bin.1   3.836403  0.903312
# 4           LAMI_RD304_D11_C1_S3_L005__CONCOCT__P.1__13  28.863895  0.998109
# ...                                                 ...        ...       ...
# 1441   LAMI_RD310_D14_C3_S21_L005__METABAT2__E.1__bin.1   0.053158  0.045549
# 1442   LAMI_RD310_D16_C2_S22_L005__METABAT2__P.1__bin.1   2.853260  0.907018
# 1443       LAMI_RD310_D21_C2_S23_L005__CONCOCT__P.1__37   3.243245  0.879607
# 1444        LAMI_RD310_D7_C3_S24_L005__GENOMAD__Virus.1  26.031026  0.999231
# 1445    LAMI_RD310_D7_C3_S24_L005__METABAT2__P.1__bin.1   2.993414  0.918685
#
#       nucl_diversity     length  true_scaffolds  detected_scaffolds  \
# 0           0.003835  6309316.0           461.0               461.0
# 1           0.000426  2428405.0            34.0                34.0
# 2           0.000411  2669129.0            53.0                53.0
# 3           0.004028  6998693.0           505.0               505.0
# 4           0.000426  2458364.0            53.0                53.0
# ...              ...        ...             ...                 ...
# 1441        0.000000  6839882.0           330.0               284.0
# 1442        0.000298  2413078.0            79.0                79.0
# 1443        0.000323  2756977.0            67.0                60.0
# 1444        0.000227     7800.0             1.0                 1.0
# 1445        0.000331  2437509.0            31.0                31.0
#
#       coverage_median  coverage_std  coverage_SEM  ...  d_prime_mean  \
# 0                   4      3.535212      0.001418  ...      0.941307
# 1                  28     10.512974      0.006756  ...      1.000000
# 2                  27     13.638062      0.008364  ...      0.993151
# 3                   3      2.976027      0.001133  ...      0.958647
# 4                  28     11.546119      0.007380  ...      1.000000
# ...               ...           ...           ...  ...           ...
# 1441                0      0.262052      0.000101  ...           NaN
# 1442                3      1.976448      0.001277  ...           NaN
# 1443                3      4.541264      0.002742  ...      1.000000
# 1444               26     10.114387      0.116028  ...           NaN
# 1445                3      2.273039      0.001458  ...      1.000000
#
#       consensus_divergent_sites  population_divergent_sites  SNS_count  \
# 0                        2716.0                       367.0      365.0
# 1                           9.0                         5.0        4.0
# 2                           6.0                         2.0        2.0
# 3                        2766.0                       587.0      583.0
# 4                           9.0                         2.0        8.0
# ...                         ...                         ...        ...
# 1441                        0.0                         0.0        0.0
# 1442                       10.0                         0.0        0.0
# 1443                        7.0                         1.0        0.0
# 1444                        0.0                         0.0        0.0
# 1445                        3.0                         2.0        2.0
#
#       SNV_count  filtered_read_pair_count  reads_unfiltered_pairs  \
# 0       15306.0                    189216                  192068
# 1        1112.0                    421375                  423357
# 2        1163.0                    445346                  447253
# 3       12154.0                    162335                  165082
# 4        1184.0                    424608                  426486
# ...         ...                       ...                     ...
# 1441        0.0                      2067                    2130
# 1442       36.0                     39696                   39975
# 1443       90.0                     51541                   51893
# 1444        0.0                      1163                    1185
# 1445       40.0                     42121                   42392
#
#       reads_mean_PID  reads_unfiltered_reads  divergent_site_count
# 0           0.995392                395806.0               15671.0
# 1           0.998291                885356.0                1116.0
# 2           0.998405                935546.0                1165.0
# 3           0.994404                341503.0               12737.0
# 4           0.998357                892297.0                1192.0
# ...              ...                     ...                   ...
# 1441        0.997336                  4685.0                   0.0
# 1442        0.998004                 93494.0                  36.0
# 1443        0.998111                119412.0                  90.0
# 1444        0.998341                  2613.0                   0.0
# 1445        0.998231                 99205.0                  42.0
#
# [1446 rows x 30 columns]

# %%
# Create sample_id column from bin name in genome column so that it matches format in sample_name of metadata
df['sample_id'] = df['genome'].str.split('_').str[:4].str.join('_')
df['sample_id'] = df['sample_id'].str.replace('_', '.')
df.head()
# Out:
#                                               genome   coverage   breadth  \
# 0     LAMI_RD304_D0_C1_S1_L005__METABAT2__E.1__bin.1   4.962335  0.951691
# 1     LAMI_RD304_D0_C1_S1_L005__METABAT2__P.1__bin.2  28.946285  0.997830
# 2  LAMI_RD304_D0_C3_S2_L005__MAXBIN2-107__P.1__bi...  27.889266  0.997830
# 3     LAMI_RD304_D0_C3_S2_L005__METABAT2__E.1__bin.1   3.836403  0.903312
# 4        LAMI_RD304_D11_C1_S3_L005__CONCOCT__P.1__13  28.863895  0.998109
#
#    nucl_diversity     length  true_scaffolds  detected_scaffolds  \
# 0        0.003835  6309316.0           461.0               461.0
# 1        0.000426  2428405.0            34.0                34.0
# 2        0.000411  2669129.0            53.0                53.0
# 3        0.004028  6998693.0           505.0               505.0
# 4        0.000426  2458364.0            53.0                53.0
#
#    coverage_median  coverage_std  coverage_SEM  ...  \
# 0                4      3.535212      0.001418  ...
# 1               28     10.512974      0.006756  ...
# 2               27     13.638062      0.008364  ...
# 3                3      2.976027      0.001133  ...
# 4               28     11.546119      0.007380  ...
#
#    consensus_divergent_sites  population_divergent_sites  SNS_count  \
# 0                     2716.0                       367.0      365.0
# 1                        9.0                         5.0        4.0
# 2                        6.0                         2.0        2.0
# 3                     2766.0                       587.0      583.0
# 4                        9.0                         2.0        8.0
#
#    SNV_count  filtered_read_pair_count  reads_unfiltered_pairs  \
# 0    15306.0                    189216                  192068
# 1     1112.0                    421375                  423357
# 2     1163.0                    445346                  447253
# 3    12154.0                    162335                  165082
# 4     1184.0                    424608                  426486
#
#    reads_mean_PID  reads_unfiltered_reads  divergent_site_count  \
# 0        0.995392                395806.0               15671.0
# 1        0.998291                885356.0                1116.0
# 2        0.998405                935546.0                1165.0
# 3        0.994404                341503.0               12737.0
# 4        0.998357                892297.0                1192.0
#
#            sample_id
# 0   LAMI.RD304.D0.C1
# 1   LAMI.RD304.D0.C1
# 2   LAMI.RD304.D0.C3
# 3   LAMI.RD304.D0.C3
# 4  LAMI.RD304.D11.C1
#
# [5 rows x 31 columns]

# %%
# Read in subsetted metadata file for wgs (only contains those 24 samples) and necessary columns
md = pd.read_csv('../Metadata/wgs_simplied_md.tsv', sep='\t')
md.head()
# Out:
#          sample_name  day subject_ID c_zone          Zone  \
# 0   LAMI.RD304.D7.C1    7     PP_304     C1      Lesional
# 1   LAMI.RD306.D0.C3    0     PP_306     C3  Non-lesional
# 2  LAMI.RD310.D21.C2   21     PP_310     C2      Lesional
# 3   LAMI.RD308.D0.C3    0     PP_308     C3  Non-lesional
# 4  LAMI.RD306.D14.C1   14     PP_306     C1      Lesional
#
#    local_lesion_severity  inflammatory_lesions_face
# 0                      4                         25
# 1                      1                          8
# 2                      4                         36
# 3                      0                         26
# 4                      1                         11

# %%
# Merge df with md based on the matching 'sample_id' and 'sample_name'
df = pd.merge(df, md[['sample_name', 'local_lesion_severity']], left_on='sample_id', right_on='sample_name', how='left')

# Drop the redundant 'sample_name' column if desired
df = df.drop('sample_name', axis=1)

# Merge the 'subject_ID' column from md into df based on matching 'sample_id' in df with 'sample_name' in md
df = df.merge(md[['sample_name', 'subject_ID']], how='left', left_on='sample_id', right_on='sample_name')

# %%
# Read in merged genome_info file
path = '../Data/metaG/VEBA_analysis/output_files/X_mags.with_taxonomy.with_slcs_name.csv'
taxa = pd.read_csv(path, sep=',')
taxa.head()
# Out:
#        SLC                                         sample_mag organism_type  \
# 0   PSLC-1  LAMI_RD306_D0_C3_S7_L005__MAXBIN2-40__P.1__bin...   prokaryotic
# 1   PSLC-2     LAMI_RD306_D0_C3_S7_L005__METABAT2__P.1__bin.2   prokaryotic
# 2   PSLC-7    LAMI_RD306_D11_C1_S8_L005__CONCOCT__P.1__14_sub   prokaryotic
# 3  PSLC-11        LAMI_RD306_D11_C1_S8_L005__CONCOCT__P.1__26   prokaryotic
# 4   PSLC-3        LAMI_RD306_D11_C1_S8_L005__CONCOCT__P.1__27   prokaryotic
#
#                                             taxonomy  \
# 0  d__Bacteria;p__Actinomycetota;c__Actinomycetia...
# 1  d__Bacteria;p__Actinomycetota;c__Actinomycetia...
# 2  d__Bacteria;p__Pseudomonadota;c__Gammaproteoba...
# 3  d__Bacteria;p__Pseudomonadota;c__Gammaproteoba...
# 4  d__Bacteria;p__Actinomycetota;c__Actinomycetia...
#
#                          name  LAMI_RD308_D9_C3_S18_L005  \
# 0         Cutibacterium acnes                     777667
# 1    Cutibacterium granulosum                      14720
# 2            Other (combined)                          5
# 3            Other (combined)                         31
# 4  Lawsonella cleavelandensis                       1217
#
#    LAMI_RD306_D28_C3_S12_L005  LAMI_RD310_D16_C2_S22_L005  \
# 0                     1513946                       19467
# 1                      171159                        1374
# 2                          74                           0
# 3                          69                           0
# 4                       72530                         123
#
#    LAMI_RD304_D14_C3_S4_L005  LAMI_RD304_D11_C1_S3_L005  ...  \
# 0                     127037                       5905  ...
# 1                      21838                        896  ...
# 2                         35                          1  ...
# 3                          3                          0  ...
# 4                       7890                        258  ...
#
#    LAMI_RD304_D28_C3_S5_L005  LAMI_RD308_D0_C2_S13_L005  \
# 0                     362236                       1811
# 1                      60647                         27
# 2                         57                          0
# 3                          4                          0
# 4                       4476                          4
#
#    LAMI_RD310_D0_C2_S19_L005  LAMI_RD306_D11_C1_S8_L005  \
# 0                     196880                     825942
# 1                      20516                      65240
# 2                          1                     102859
# 3                          1                     764138
# 4                        661                      94133
#
#    LAMI_RD310_D0_C3_S20_L005  LAMI_RD310_D14_C3_S21_L005  \
# 0                     372845                      441798
# 1                      26311                       13760
# 2                          5                           1
# 3                          0                           0
# 4                        819                         446
#
#    LAMI_RD306_D14_C1_S9_L005  LAMI_RD310_D21_C2_S23_L005  \
# 0                      83571                      196812
# 1                       5157                       28370
# 2                         22                          13
# 3                         25                           0
# 4                      11267                         970
#
#    LAMI_RD308_D14_C3_S16_L005  LAMI_RD304_D0_C1_S1_L005
# 0                      782381                    111499
# 1                        7988                     23177
# 2                           1                        35
# 3                           3                         1
# 4                         635                      2289
#
# [5 rows x 29 columns]

# %%
# Merge the 'taxonomy' column from taxa into df based on matching 'genome' in df with 'Unnamed:1' in taxa
df = df.merge(taxa[['sample_mag', 'name']], how='left', left_on='genome', right_on='sample_mag')
df = df.drop(columns=['sample_mag'])

# Add zone info 
df = df.merge(md[['sample_name', 'Zone']], how='left', left_on='sample_id', right_on='sample_name')
df = df.drop(columns=['sample_name_x', 'sample_name_y'])

# Drop genomes where the SNV_count value is NaN
df = df.dropna(subset=['SNV_count'])

print(f'Number of genomes is: {len(df.index)}')

df.head()
# Out:
# Number of genomes is: 1446
#                                               genome   coverage   breadth  \
# 0     LAMI_RD304_D0_C1_S1_L005__METABAT2__E.1__bin.1   4.962335  0.951691
# 1     LAMI_RD304_D0_C1_S1_L005__METABAT2__P.1__bin.2  28.946285  0.997830
# 2  LAMI_RD304_D0_C3_S2_L005__MAXBIN2-107__P.1__bi...  27.889266  0.997830
# 3     LAMI_RD304_D0_C3_S2_L005__METABAT2__E.1__bin.1   3.836403  0.903312
# 4        LAMI_RD304_D11_C1_S3_L005__CONCOCT__P.1__13  28.863895  0.998109
#
#    nucl_diversity     length  true_scaffolds  detected_scaffolds  \
# 0        0.003835  6309316.0           461.0               461.0
# 1        0.000426  2428405.0            34.0                34.0
# 2        0.000411  2669129.0            53.0                53.0
# 3        0.004028  6998693.0           505.0               505.0
# 4        0.000426  2458364.0            53.0                53.0
#
#    coverage_median  coverage_std  coverage_SEM  ...  filtered_read_pair_count  \
# 0                4      3.535212      0.001418  ...                    189216
# 1               28     10.512974      0.006756  ...                    421375
# 2               27     13.638062      0.008364  ...                    445346
# 3                3      2.976027      0.001133  ...                    162335
# 4               28     11.546119      0.007380  ...                    424608
#
#    reads_unfiltered_pairs  reads_mean_PID  reads_unfiltered_reads  \
# 0                  192068        0.995392                395806.0
# 1                  423357        0.998291                885356.0
# 2                  447253        0.998405                935546.0
# 3                  165082        0.994404                341503.0
# 4                  426486        0.998357                892297.0
#
#    divergent_site_count          sample_id  local_lesion_severity  subject_ID  \
# 0               15671.0   LAMI.RD304.D0.C1                      3      PP_304
# 1                1116.0   LAMI.RD304.D0.C1                      3      PP_304
# 2                1165.0   LAMI.RD304.D0.C3                      0      PP_304
# 3               12737.0   LAMI.RD304.D0.C3                      0      PP_304
# 4                1192.0  LAMI.RD304.D11.C1                      2      PP_304
#
#                   name          Zone
# 0      Malassezia spp.      Lesional
# 1  Cutibacterium acnes      Lesional
# 2  Cutibacterium acnes  Non-lesional
# 3      Malassezia spp.  Non-lesional
# 4  Cutibacterium acnes      Lesional
#
# [5 rows x 35 columns]

# %%
# Get the maximum value in the 'SNV_count' column
max_value = df['SNV_count'].max()

# Get the minimum value in the 'breath' column
min_value = df['SNV_count'].min()

# Print the results
print(f"Max SNV_count: {max_value}")
print(f"Min SNV_count: {min_value}")
# Out:
# Max SNV_count: 66787.0
# Min SNV_count: 0.0

# %%
# Get the maximum value in the 'breadth' column
max_value = df['breadth'].max()

# Get the minimum value in the 'breath' column
min_value = df['breadth'].min()

# Print the results
print(f"Max breadth: {max_value}")
print(f"Min breadth: {min_value}")
# Out:
# Max breadth: 1.0
# Min breadth: 3.611944266255188e-05

# %%
# Get the maximum value in the 'coverage' column
max_value = df['coverage'].max()

# Get the minimum value in the 'coverage' column
min_value = df['coverage'].min()

# Print the results
print(f"Max coverage: {max_value}")
print(f"Min coverage: {min_value}")
# Out:
# Max coverage: 1548.586903067167
# Min coverage: 4.186638807428166e-05

# %%
# Filter the DataFrame for SNV_count > 0
df = df[(df['SNV_count'] > 0.0)]

print(f'Number of genomes is now: {len(df.index)}')

# Sort values by SNV_count column
df_sorted = df.sort_values(by='SNV_count', ascending=False)

df_sorted.head()
# Out:
# Number of genomes is now: 1012
#                                                 genome   coverage   breadth  \
# 604   LAMI_RD306_D14_C3_S10_L005__METABAT2__E.1__bin.1  11.972306  0.986007
# 570     LAMI_RD304_D0_C3_S2_L005__METABAT2__E.1__bin.1   4.633991  0.925421
# 758  LAMI_RD306_D28_C3_S12_L005__METABAT2__P.1__bin.10  12.829588  0.991404
# 742   LAMI_RD306_D14_C3_S10_L005__METABAT2__E.1__bin.1   5.327534  0.874079
# 567     LAMI_RD304_D0_C1_S1_L005__METABAT2__E.1__bin.1   4.581981  0.925781
#
#      nucl_diversity     length  true_scaffolds  detected_scaffolds  \
# 604        0.006513  5848576.0           840.0               840.0
# 570        0.008278  6998693.0           505.0               505.0
# 758        0.011504  1651758.0           515.0               515.0
# 742        0.007968  5848576.0           840.0               840.0
# 567        0.007848  6309316.0           461.0               461.0
#
#      coverage_median  coverage_std  coverage_SEM  ...  \
# 604               11      6.820955      0.002862  ...
# 570                4      3.758542      0.001431  ...
# 758               13      5.862110      0.004710  ...
# 742                4      5.323033      0.002233  ...
# 567                4      3.536978      0.001419  ...
#
#      filtered_read_pair_count  reads_unfiltered_pairs  reads_mean_PID  \
# 604                    447336                  459812        0.991484
# 570                    207969                  217601        0.988215
# 758                    139431                  145407        0.987529
# 742                    196928                  204983        0.989906
# 567                    185948                  193749        0.989212
#
#      reads_unfiltered_reads  divergent_site_count          sample_id  \
# 604                 72762.0              926214.0  LAMI.RD306.D14.C3
# 570                 43034.0              441025.0   LAMI.RD304.D0.C3
# 758                 36100.0              298088.0  LAMI.RD306.D28.C3
# 742                 38229.0              415261.0  LAMI.RD306.D14.C3
# 567                 35541.0              392432.0   LAMI.RD304.D0.C1
#
#      local_lesion_severity  subject_ID             name          Zone
# 604                      0      PP_306  Malassezia spp.  Non-lesional
# 570                      0      PP_304  Malassezia spp.  Non-lesional
# 758                      1      PP_306      Micrococcus  Non-lesional
# 742                      0      PP_306  Malassezia spp.  Non-lesional
# 567                      3      PP_304  Malassezia spp.      Lesional
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Nucleotide diversity results from inStrain based on MAGs grouped at species level

# %%
# Filter the DataFrame for Non-lesional and Lesional samples and key microbes
key_microbes = ['Lawsonella cleavelandensis', 'Malassezia spp.', 'Papillomaviridae', 'Cutibacterium acnes', 'Cutibacterium granulosum', 'Caudoviricetes', 'Corynebacterium spp.', 'Neisseria spp.', 'Micrococcus', 'Other (combined)']
df_key_microbes = df[(df['name'].isin(key_microbes)) & (df['Zone'].isin(['Non-lesional', 'Lesional']))]

# Create a new row with 'All MAGs' to represent combined nucl diversity for all microbes
df_all_mags = df[df['Zone'].isin(['Non-lesional', 'Lesional'])].copy()
df_all_mags['name'] = 'All MAGs'

# Combine the "All MAGs" row with the filtered key microbes DataFrame
df_combined = pd.concat([df_all_mags, df_key_microbes])

# Define a new color palette for Lesional and Non-lesional samples
palette_zone = {'Lesional': '#FF6347',  # Tomato Red
                'Non-lesional': '#6495ED'}  # Cornflower Blue

# %%
# Initialize a list to store results
results = []

# Perform pairwise Mann-Whitney U test for each microbe, including All MAGs
for microbe in df_combined['name'].unique():
    # Subset the data for the current microbe or All MAGs
    microbe_data = df_combined[df_combined['name'] == microbe]
    
    # Split the data into Non-lesional and Lesional groups
    non_lesional = microbe_data[microbe_data['Zone'] == 'Non-lesional']['SNV_count']
    lesional = microbe_data[microbe_data['Zone'] == 'Lesional']['SNV_count']
    
    # Perform Mann-Whitney U test
    if len(non_lesional) > 0 and len(lesional) > 0:  # Ensure there are data points in both groups
        stat, p_value = mannwhitneyu(non_lesional, lesional, alternative='two-sided')
        # Append the results
        results.append({'Microbe': microbe, 'p_value': p_value})
    else:
        results.append({'Microbe': microbe, 'p_value': float('nan')})  # Append NaN if one group is empty

# Convert results to a DataFrame
results_df = pd.DataFrame(results)

# Sort by p-value
results_df = results_df.sort_values('p_value')

# Remove 'ALL MAGs' as this is biased by differential representation of MAGs from different taxa that have inherently different nucleotide diversity
results_df = results_df[results_df['Microbe'] != 'All MAGs']

# See results
results_df
# Out:
#                        Microbe   p_value
# 5             Other (combined)  0.002285
# 7               Neisseria spp.  0.034350
# 3     Cutibacterium granulosum  0.159014
# 10              Caudoviricetes  0.221833
# 2          Cutibacterium acnes  0.330006
# 4   Lawsonella cleavelandensis  0.434307
# 1              Malassezia spp.  0.652480
# 6         Corynebacterium spp.  0.655900
# 8             Papillomaviridae  0.696270
# 9                  Micrococcus       NaN

# %%
# Perform pairwise Mann-Whitney U test for each microbe, including All MAGs
results = []

# Get unique values in 'name' column, excluding 'All MAGs'
unique_microbes = [microbe for microbe in df_combined['name'].unique() if microbe != 'All MAGs']

for microbe in unique_microbes:
    # Subset the data for the current microbe or All MAGs
    microbe_data = df_combined[df_combined['name'] == microbe]
    
    # Split the data into Non-lesional and Lesional groups
    non_lesional = microbe_data[microbe_data['Zone'] == 'Non-lesional']['nucl_diversity']
    lesional = microbe_data[microbe_data['Zone'] == 'Lesional']['nucl_diversity']
    
    # Perform Mann-Whitney U test
    if len(non_lesional) > 0 and len(lesional) > 0:  # Ensure there are data points in both groups
        stat, p_value = mannwhitneyu(non_lesional, lesional, alternative='two-sided')
        results.append({'Microbe': microbe, 'p_value': p_value})
    else:
        results.append({'Microbe': microbe, 'p_value': float('nan')})  # Append NaN if one group is empty

# Convert results to a DataFrame
results_df = pd.DataFrame(results)

# Define a new color palette for Lesional and Non-lesional samples
palette_zone = {'Lesional': '#FF6347',  # Tomato Red
                'Non-lesional': '#7AC9D5'}  # Blue Green

# Define the desired order of microbes
microbe_order = ['Cutibacterium acnes', 'Cutibacterium granulosum', 'Malassezia spp.', 'Papillomaviridae', 
                 'Caudoviricetes', 'Lawsonella cleavelandensis', 'Corynebacterium spp.', 'Neisseria spp.', 'Micrococcus', 'Other (combined)']

# Create boxplot for each microbe with zone (Non-lesional vs Lesional), including All MAGs
plt.figure(figsize=(12, 6))
sns.boxplot(x='name', y='nucl_diversity', hue='Zone', data=df_combined, 
            palette=palette_zone, hue_order=['Non-lesional', 'Lesional'], order=microbe_order, showfliers=False)

# Rotate x-axis labels for clarity
plt.xticks(rotation=45)

# Set y-axis to log scale for better visualization of differences
plt.yscale('log')
plt.yticks([1e-4, 1e-3, 1e-2], ['10$^{-4}$', '10$^{-3}$', '10$^{-2}$'])

# Add labels and title
plt.xlabel('')
plt.ylabel('Nucleotide Diversity ($\pi$)')
plt.title('Nucleotide Diversity of Species-Level MAGs')

# Iterate over the results to add significance lines and asterisks for significant p-values
for i, row in results_df.iterrows():
    # Only proceed if the p-value is <= 0.05
    if row['p_value'] <= 0.05:
        # Determine the significance label based on p-value thresholds
        if row['p_value'] < 0.001:
            significance = '***  ' + f"{row['p_value']:.2e}"
        elif row['p_value'] < 0.01:
            significance = '**  ' + f"{row['p_value']:.2e}"
        else:
            significance = '*  ' + f"{row['p_value']:.2e}"

        # Get the x position of the current microbe based on its index in microbe_order
        microbe_idx = microbe_order.index(row['Microbe'])
        x1 = microbe_idx - 0.2  # Position for Non-lesional
        x2 = microbe_idx + 0.2  # Position for Lesional
        y = df_combined[df_combined['name'] == row['Microbe']]['nucl_diversity'].max() * 1.1  # Max y position

        # Draw the horizontal line and display the significance
        plt.plot([x1, x2], [y, y], color='k', lw=1.5)

        # Add an asterisk above the line, based on significance level
        plt.text((x1 + x2) / 2, y * 1, significance, ha='center', va='bottom', color='black')

# Display the plot
plt.tight_layout()

# Save and show the figure
plt.savefig(f'../Figures/metaG_Figures/inStrain/inStrain_nucleotide_diversity_species.png', dpi=600, bbox_inches='tight', pad_inches=0.1)  # Save as png
plt.savefig(f'../Figures/metaG_Figures/inStrain/inStrain_nucleotide_diversity_species.svg')  # Save as svg
plt.show()
# Out:
# <>:47: SyntaxWarning: invalid escape sequence '\p'
# <>:47: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/22/yck9vwx53w1c38tvj_c0_tz00000gn/T/ipykernel_60524/1175376348.py:47: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel('Nucleotide Diversity ($\pi$)')

# %%
# Perform pairwise Mann-Whitney U test for each microbe, including All MAGs
results = []

# Get unique values in 'name' column, excluding 'All MAGs'
unique_microbes = ['Cutibacterium acnes', 'Corynebacterium spp.', 'Lawsonella cleavelandensis']

for microbe in unique_microbes:
    # Subset the data for the current microbe or All MAGs
    microbe_data = df_combined[df_combined['name'] == microbe]
    
    # Split the data into Non-lesional and Lesional groups
    non_lesional = microbe_data[microbe_data['Zone'] == 'Non-lesional']['nucl_diversity']
    lesional = microbe_data[microbe_data['Zone'] == 'Lesional']['nucl_diversity']
    
    # Perform Mann-Whitney U test
    if len(non_lesional) > 0 and len(lesional) > 0:  # Ensure there are data points in both groups
        stat, p_value = mannwhitneyu(non_lesional, lesional, alternative='two-sided')
        results.append({'Microbe': microbe, 'p_value': p_value})
    else:
        results.append({'Microbe': microbe, 'p_value': float('nan')})  # Append NaN if one group is empty

# Convert results to a DataFrame
results_df = pd.DataFrame(results)

# Define a new color palette for Lesional and Non-lesional samples
palette_zone = {'Lesional': '#FF6347',  # Tomato Red
                'Non-lesional': '#7AC9D5'}  # Blue Green

# Define the desired order of microbes
microbe_order = ['Cutibacterium acnes', 'Corynebacterium spp.', 'Lawsonella cleavelandensis']

# Create boxplot for each microbe with zone (Non-lesional vs Lesional), including All MAGs
plt.figure(figsize=(8, 6))
sns.boxplot(x='name', y='nucl_diversity', hue='Zone', data=df_combined, 
            palette=palette_zone, hue_order=['Non-lesional', 'Lesional'], order=microbe_order, showfliers=False)

# Rotate x-axis labels for clarity
# plt.xticks(rotation=45)

# Set y-axis to log scale for better visualization of differences
plt.yscale('log')
plt.yticks([1e-4, 1e-3, 1e-2], ['10$^{-4}$', '10$^{-3}$', '10$^{-2}$'])

# Add labels and title
plt.xlabel('')
plt.ylabel('Nucleotide Diversity ($\pi$)')
plt.title('Nucleotide Diversity of Species-Level MAGs')

# Iterate over the results to add significance lines and asterisks for significant p-values
for i, row in results_df.iterrows():
    # Only proceed if the p-value is <= 0.05
    if row['p_value'] <= 0.05:
        # Determine the significance label based on p-value thresholds
        if row['p_value'] < 0.001:
            significance = '***  ' + f"{row['p_value']:.2e}"
        elif row['p_value'] < 0.01:
            significance = '**  ' + f"{row['p_value']:.2e}"
        else:
            significance = '*  ' + f"{row['p_value']:.2e}"

        # Get the x position of the current microbe based on its index in microbe_order
        microbe_idx = microbe_order.index(row['Microbe'])
        x1 = microbe_idx - 0.2  # Position for Non-lesional
        x2 = microbe_idx + 0.2  # Position for Lesional
        y = df_combined[df_combined['name'] == row['Microbe']]['nucl_diversity'].max() * 1.1  # Max y position

        # Draw the horizontal line and display the significance
        plt.plot([x1, x2], [y, y], color='k', lw=1.5)

        # Add an asterisk above the line, based on significance level
        plt.text((x1 + x2) / 2, y * 1, significance, ha='center', va='bottom', color='black')

# Display the plot
plt.tight_layout()

# Save and show the figure
plt.savefig(f'../Figures/metaG_Figures/inStrain/inStrain_nucleotide_diversity_top3.png', dpi=600, bbox_inches='tight', pad_inches=0.1)  # Save as png
plt.savefig(f'../Figures/metaG_Figures/inStrain/inStrain_nucleotide_diversity_top3.svg')  # Save as svg
plt.show()
# Out:
# <>:46: SyntaxWarning: invalid escape sequence '\p'
# <>:46: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/22/yck9vwx53w1c38tvj_c0_tz00000gn/T/ipykernel_60524/1239198325.py:46: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel('Nucleotide Diversity ($\pi$)')

# %% [markdown]
# ## Nucleotide diversity results from inStrain based on MAGs grouped by _C. acnes_ MLST strain type

# %%
# Read in merged genome_info file
path = '../Data/metaG/VEBA_analysis/output_files/X_mags.with_taxonomy.with_slcs_c.acnes.csv'
taxa = pd.read_csv(path, sep=',')
taxa.head()
# Out:
#        SLC                                         sample_mag organism_type  \
# 0   PSLC-1  LAMI_RD306_D0_C3_S7_L005__MAXBIN2-40__P.1__bin...   prokaryotic
# 1   PSLC-2     LAMI_RD306_D0_C3_S7_L005__METABAT2__P.1__bin.2   prokaryotic
# 2   PSLC-7    LAMI_RD306_D11_C1_S8_L005__CONCOCT__P.1__14_sub   prokaryotic
# 3  PSLC-11        LAMI_RD306_D11_C1_S8_L005__CONCOCT__P.1__26   prokaryotic
# 4   PSLC-3        LAMI_RD306_D11_C1_S8_L005__CONCOCT__P.1__27   prokaryotic
#
#                                             taxonomy  \
# 0  d__Bacteria;p__Actinomycetota;c__Actinomycetia...
# 1  d__Bacteria;p__Actinomycetota;c__Actinomycetia...
# 2  d__Bacteria;p__Pseudomonadota;c__Gammaproteoba...
# 3  d__Bacteria;p__Pseudomonadota;c__Gammaproteoba...
# 4  d__Bacteria;p__Actinomycetota;c__Actinomycetia...
#
#                     c. acnes  LAMI_RD308_D9_C3_S18_L005  \
# 0   C. acnes Type IA (MAG 1)                     777667
# 1                        NaN                      14720
# 2                        NaN                          5
# 3                        NaN                         31
# 4                        NaN                       1217
#
#    LAMI_RD306_D28_C3_S12_L005  LAMI_RD310_D16_C2_S22_L005  \
# 0                     1513946                       19467
# 1                      171159                        1374
# 2                          74                           0
# 3                          69                           0
# 4                       72530                         123
#
#    LAMI_RD304_D14_C3_S4_L005  LAMI_RD304_D11_C1_S3_L005  ...  \
# 0                     127037                       5905  ...
# 1                      21838                        896  ...
# 2                         35                          1  ...
# 3                          3                          0  ...
# 4                       7890                        258  ...
#
#    LAMI_RD304_D28_C3_S5_L005  LAMI_RD308_D0_C2_S13_L005  \
# 0                     362236                       1811
# 1                      60647                         27
# 2                         57                          0
# 3                          4                          0
# 4                       4476                          4
#
#    LAMI_RD310_D0_C2_S19_L005  LAMI_RD306_D11_C1_S8_L005  \
# 0                     196880                     825942
# 1                      20516                      65240
# 2                          1                     102859
# 3                          1                     764138
# 4                        661                      94133
#
#    LAMI_RD310_D0_C3_S20_L005  LAMI_RD310_D14_C3_S21_L005  \
# 0                     372845                      441798
# 1                      26311                       13760
# 2                          5                           1
# 3                          0                           0
# 4                        819                         446
#
#    LAMI_RD306_D14_C1_S9_L005  LAMI_RD310_D21_C2_S23_L005  \
# 0                      83571                      196812
# 1                       5157                       28370
# 2                         22                          13
# 3                         25                           0
# 4                      11267                         970
#
#    LAMI_RD308_D14_C3_S16_L005  LAMI_RD304_D0_C1_S1_L005
# 0                      782381                    111499
# 1                        7988                     23177
# 2                           1                        35
# 3                           3                         1
# 4                         635                      2289
#
# [5 rows x 29 columns]

# %%
# Merge the 'taxonomy' column from taxa into df based on matching 'genome' in df with 'Unnamed:1' in taxa
df = df.merge(taxa[['sample_mag', 'c. acnes']], how='left', left_on='genome', right_on='sample_mag')
df = df.drop(columns=['sample_mag'])

# Add zone info 
df = df.merge(md[['sample_name', 'Zone']], how='left', left_on='sample_id', right_on='sample_name')

# Drop genomes where nucl_diverity is NaN
df = df.dropna(subset=['nucl_diversity'])

# Filter the DataFrame for nucl_diversity > 0
df = df[(df['nucl_diversity'] > 0.0)]

# %%
# Get the maximum value in the 'nucl_diversity' column
max_value = df['nucl_diversity'].max()

# Get the minimum value in the 'breath' column
min_value = df['nucl_diversity'].min()

# Print the results
print(f"Max nucl_diversity: {max_value}")
print(f"Min nucl_diversity: {min_value}")
# Out:
# Max nucl_diversity: 0.0208695660466733
# Min nucl_diversity: 0.0001193115662337

# %%
# Get the maximum value in the 'breadth' column
max_value = df['breadth'].max()

# Get the minimum value in the 'breath' column
min_value = df['breadth'].min()

# Print the results
print(f"Max breadth: {max_value}")
print(f"Min breadth: {min_value}")
# Out:
# Max breadth: 0.9999323295550668
# Min breadth: 0.0006918139730639

# %%
# Sort by nucl_diversity column
df = df.sort_values(by='nucl_diversity', ascending=False)

# Rename Zone_x to Zone
df = df.rename(columns={'Zone_x': 'Zone'})

# Drop the Zone_y column
df = df.drop(columns=['Zone_y'])

df.head()
# Out:
#                                                 genome  coverage   breadth  \
# 922        LAMI_RD306_D23_C1_S11_L005__CONCOCT__P.1__4  0.032903  0.028253
# 143    LAMI_RD308_D23_C2_S17_L005__CONCOCT__P.1__3_sub  1.311266  0.495348
# 710  LAMI_RD306_D28_C3_S12_L005__MAXBIN2-107__P.2__...  2.859724  0.556719
# 188    LAMI_RD308_D23_C2_S17_L005__CONCOCT__P.1__3_sub  0.099173  0.072122
# 473       LAMI_RD306_D14_C3_S10_L005__GENOMAD__Virus.2  5.587592  0.791820
#
#      nucl_diversity     length  true_scaffolds  detected_scaffolds  \
# 922        0.020870  2271160.0           116.0                95.0
# 143        0.017373  1239730.0           441.0               400.0
# 710        0.015418  2177234.0           946.0               749.0
# 188        0.014762  1239730.0           441.0               244.0
# 473        0.014069    29095.0             1.0                 1.0
#
#      coverage_median  coverage_std  coverage_SEM  ...  reads_mean_PID  \
# 922                0      0.209191      0.000140  ...        0.980361
# 143                1      1.955700      0.001822  ...        0.956687
# 710                1      3.985881      0.002827  ...        0.977361
# 188                0      0.415691      0.000387  ...        0.954242
# 473                2      7.644102      0.044970  ...        0.961706
#
#      reads_unfiltered_reads  divergent_site_count          sample_id  \
# 922                  1184.0                   4.0  LAMI.RD306.D23.C1
# 143                  3088.0               34567.0  LAMI.RD308.D23.C2
# 710                 16184.0               96968.0  LAMI.RD306.D28.C3
# 188                    26.0                2748.0  LAMI.RD308.D23.C2
# 473                  3217.0                 405.0  LAMI.RD306.D14.C3
#
#      local_lesion_severity  subject_ID                  name          Zone  \
# 922                      2      PP_306  Corynebacterium spp.      Lesional
# 143                      4      PP_308   Streptococcus mitis      Lesional
# 710                      1      PP_306      Other (combined)  Non-lesional
# 188                      4      PP_308   Streptococcus mitis      Lesional
# 473                      0      PP_306        Caudoviricetes  Non-lesional
#
#      c. acnes        sample_name
# 922       NaN  LAMI.RD306.D23.C1
# 143       NaN  LAMI.RD308.D23.C2
# 710       NaN  LAMI.RD306.D28.C3
# 188       NaN  LAMI.RD308.D23.C2
# 473       NaN  LAMI.RD306.D14.C3
#
# [5 rows x 37 columns]

# %%
# Extract the 'C. acnes Type **' part
df['c. acnes'] = df['c. acnes'].str.extract(r'(C\. acnes Type \S+)')

# Filter rows where the 'c. acnes' column has non-null values
df = df[df['c. acnes'].notna()]
df.head()
# Out:
#                                                 genome   coverage   breadth  \
# 990  LAMI_RD306_D11_C1_S8_L005__MAXBIN2-40__P.1__bi...   1.301884  0.677695
# 471  LAMI_RD306_D14_C1_S9_L005__MAXBIN2-107__P.1__b...  78.123701  0.999332
# 464  LAMI_RD306_D0_C3_S7_L005__MAXBIN2-40__P.1__bin...  75.706135  0.997471
# 474  LAMI_RD306_D14_C3_S10_L005__MAXBIN2-107__P.1__...  76.065363  0.999347
# 484  LAMI_RD306_D28_C3_S12_L005__MAXBIN2-107__P.1__...  77.565046  0.999498
#
#      nucl_diversity     length  true_scaffolds  detected_scaffolds  \
# 990        0.001026  2518872.0            21.0                21.0
# 471        0.000989  2474277.0            24.0                24.0
# 464        0.000972  2504338.0            33.0                33.0
# 474        0.000965  2521045.0            22.0                22.0
# 484        0.000961  2449784.0            35.0                35.0
#
#      coverage_median  coverage_std  coverage_SEM  ...  reads_mean_PID  \
# 990                1      1.335021      0.000842  ...        0.997679
# 471               80     33.969821      0.021617  ...        0.997683
# 464               79     28.564490      0.018074  ...        0.997771
# 474               79     31.460426      0.019831  ...        0.997523
# 484               80     29.828279      0.019085  ...        0.997633
#
#      reads_unfiltered_reads  divergent_site_count          sample_id  \
# 990                 44887.0                  71.0  LAMI.RD306.D11.C1
# 471               2462312.0                4452.0  LAMI.RD306.D14.C1
# 464               2413175.0                4334.0   LAMI.RD306.D0.C3
# 474               2438875.0                4425.0  LAMI.RD306.D14.C3
# 484               2421567.0                4149.0  LAMI.RD306.D28.C3
#
#      local_lesion_severity  subject_ID                 name          Zone  \
# 990                      2      PP_306  Cutibacterium acnes      Lesional
# 471                      1      PP_306  Cutibacterium acnes      Lesional
# 464                      1      PP_306  Cutibacterium acnes  Non-lesional
# 474                      0      PP_306  Cutibacterium acnes  Non-lesional
# 484                      1      PP_306  Cutibacterium acnes  Non-lesional
#
#              c. acnes        sample_name
# 990  C. acnes Type IA  LAMI.RD306.D11.C1
# 471  C. acnes Type IA  LAMI.RD306.D14.C1
# 464  C. acnes Type IA   LAMI.RD306.D0.C3
# 474  C. acnes Type IA  LAMI.RD306.D14.C3
# 484  C. acnes Type IA  LAMI.RD306.D28.C3
#
# [5 rows x 37 columns]

# %%
# Filter the DataFrame for Non-lesional and Lesional samples and key microbes
key_microbes = ['C. acnes Type IA', 'C. acnes Type IB', 'C. acnes Type II']
df_key_microbes = df[(df['c. acnes'].isin(key_microbes)) & (df['Zone'].isin(['Non-lesional', 'Lesional']))]

# Create a new row with 'All MAGs' to represent combined nucleotide diversity for all microbes
# df_all_mags = df[df['zone'].isin(['Non-lesional', 'Lesional'])].copy()
# df_all_mags['c. acnes'] = 'All MAGs'

# Combine the "All MAGs" row with the filtered key microbes DataFrame
df_combined = pd.concat([df_key_microbes])

# Define a new color palette for Lesional and Non-lesional samples
palette_zone = {'Lesional': '#FF6347',  # Tomato Red
                'Non-lesional': '#7AC9D5'}  # Cornflower Blue

# Create boxplot for each microbe with zone (Non-lesional vs Lesional), including All MAGs
plt.figure(figsize=(6, 6))
sns.boxplot(x='c. acnes', y='nucl_diversity', hue='Zone', data=df_combined, 
            palette=palette_zone, hue_order=['Non-lesional', 'Lesional'], showfliers=False, order=key_microbes)

# Rotate x-axis labels for clarity
plt.xticks(rotation=45)

# Set y-axis to log scale for better visualization of differences
plt.yscale('log')
plt.yticks([1e-4, 1e-3, 1e-2], ['10$^{-4}$', '10$^{-3}$', '10$^{-2}$'])

# Add labels, title, and tight layout format
plt.xlabel('')
plt.ylabel('Nucleotide Diversity ($\pi$)')
plt.title('Nucleotide Diversity of MLST-typed Cutibacterium acnes Strains')
plt.tight_layout()

# Save and show the figure
plt.savefig(f'../Figures/metaG_Figures/inStrain/inStrain_nucleotide_diversity_cacnes.png', dpi=600, bbox_inches='tight', pad_inches=0.1)  # Save as png
plt.savefig(f'../Figures/metaG_Figures/inStrain/inStrain_nucleotide_diversity_cacnes.svg')  # Save as svg
plt.show()
# Out:
# <>:30: SyntaxWarning: invalid escape sequence '\p'
# <>:30: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/22/yck9vwx53w1c38tvj_c0_tz00000gn/T/ipykernel_60524/2489096465.py:30: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel('Nucleotide Diversity ($\pi$)')

# %% [markdown]
# ## dN/dS analysis from inStrain profile using --gene (prodigal .fna file)

# %%
# Read in concatenated gene info file which contains dNdS_substitutions column
gene_info = pd.read_csv('../Data/metaG/inStrain_files/all_gene_info.tsv', sep='\t')

# %%
# Add genome column from all_SNP_mutation_types file
all_SNP_mutation_types = pd.read_csv('../Data/metaG/inStrain_files/all_SNP_mutation_types_with_genome.csv')

# Merge gene_info_df with all_SNP_mutation_types_df on the 'scaffold' column to add the 'genome' column
gene_info = gene_info.merge(all_SNP_mutation_types[['scaffold', 'genome']], on='scaffold', how='left')

# Remove rows where 'dNdS_substitutions' is NaN
gene_info = gene_info.dropna(subset=['dNdS_substitutions'])

# Check dataframe
gene_info.head()
# Out:
#                                                  scaffold  \
# 332767  LAMI_RD304_D0_C3_S2_L005__NODE_2_length_369923...
# 332768  LAMI_RD304_D0_C3_S2_L005__NODE_2_length_369923...
# 332769  LAMI_RD304_D0_C3_S2_L005__NODE_2_length_369923...
# 332770  LAMI_RD304_D0_C3_S2_L005__NODE_2_length_369923...
# 332771  LAMI_RD304_D0_C3_S2_L005__NODE_2_length_369923...
#
#                                                      gene  gene_length  \
# 332767  LAMI_RD304_D0_C3_S2_L005__NODE_2_length_369923...       1431.0
# 332768  LAMI_RD304_D0_C3_S2_L005__NODE_2_length_369923...       1431.0
# 332769  LAMI_RD304_D0_C3_S2_L005__NODE_2_length_369923...       1431.0
# 332770  LAMI_RD304_D0_C3_S2_L005__NODE_2_length_369923...       1431.0
# 332771  LAMI_RD304_D0_C3_S2_L005__NODE_2_length_369923...       1431.0
#
#          coverage   breadth  breadth_minCov  nucl_diversity  start    end  \
# 332767  44.324249  0.995807        0.984626        0.002901  86168  87598
# 332768  44.324249  0.995807        0.984626        0.002901  86168  87598
# 332769  44.324249  0.995807        0.984626        0.002901  86168  87598
# 332770  44.324249  0.995807        0.984626        0.002901  86168  87598
# 332771  44.324249  0.995807        0.984626        0.002901  86168  87598
#
#         direction  ...  dNdS_substitutions  pNpS_variants  SNV_count  \
# 332767          1  ...                 0.0       0.198086       14.0
# 332768          1  ...                 0.0       0.198086       14.0
# 332769          1  ...                 0.0       0.198086       14.0
# 332770          1  ...                 0.0       0.198086       14.0
# 332771          1  ...                 0.0       0.198086       14.0
#
#         SNV_S_count  SNV_N_count  SNS_count  SNS_S_count  SNS_N_count  \
# 332767          9.0          5.0        1.0          1.0          0.0
# 332768          9.0          5.0        1.0          1.0          0.0
# 332769          9.0          5.0        1.0          1.0          0.0
# 332770          9.0          5.0        1.0          1.0          0.0
# 332771          9.0          5.0        1.0          1.0          0.0
#
#         divergent_site_count  \
# 332767                  15.0
# 332768                  15.0
# 332769                  15.0
# 332770                  15.0
# 332771                  15.0
#
#                                                    genome
# 332767  LAMI_RD304_D0_C3_S2_L005__MAXBIN2-107__P.1__bi...
# 332768  LAMI_RD304_D0_C3_S2_L005__MAXBIN2-107__P.1__bi...
# 332769  LAMI_RD304_D0_C3_S2_L005__MAXBIN2-107__P.1__bi...
# 332770  LAMI_RD304_D0_C3_S2_L005__MAXBIN2-107__P.1__bi...
# 332771  LAMI_RD304_D0_C3_S2_L005__MAXBIN2-107__P.1__bi...
#
# [5 rows x 21 columns]

# %%
# Read in merged genome_info file
path = '../Data/metaG/VEBA_analysis/output_files/X_mags.with_taxonomy.with_slcs_name.csv'
taxa = pd.read_csv(path, sep=',')
taxa.head()
# Out:
#        SLC                                         sample_mag organism_type  \
# 0   PSLC-1  LAMI_RD306_D0_C3_S7_L005__MAXBIN2-40__P.1__bin...   prokaryotic
# 1   PSLC-2     LAMI_RD306_D0_C3_S7_L005__METABAT2__P.1__bin.2   prokaryotic
# 2   PSLC-7    LAMI_RD306_D11_C1_S8_L005__CONCOCT__P.1__14_sub   prokaryotic
# 3  PSLC-11        LAMI_RD306_D11_C1_S8_L005__CONCOCT__P.1__26   prokaryotic
# 4   PSLC-3        LAMI_RD306_D11_C1_S8_L005__CONCOCT__P.1__27   prokaryotic
#
#                                             taxonomy  \
# 0  d__Bacteria;p__Actinomycetota;c__Actinomycetia...
# 1  d__Bacteria;p__Actinomycetota;c__Actinomycetia...
# 2  d__Bacteria;p__Pseudomonadota;c__Gammaproteoba...
# 3  d__Bacteria;p__Pseudomonadota;c__Gammaproteoba...
# 4  d__Bacteria;p__Actinomycetota;c__Actinomycetia...
#
#                          name  LAMI_RD308_D9_C3_S18_L005  \
# 0         Cutibacterium acnes                     777667
# 1    Cutibacterium granulosum                      14720
# 2            Other (combined)                          5
# 3            Other (combined)                         31
# 4  Lawsonella cleavelandensis                       1217
#
#    LAMI_RD306_D28_C3_S12_L005  LAMI_RD310_D16_C2_S22_L005  \
# 0                     1513946                       19467
# 1                      171159                        1374
# 2                          74                           0
# 3                          69                           0
# 4                       72530                         123
#
#    LAMI_RD304_D14_C3_S4_L005  LAMI_RD304_D11_C1_S3_L005  ...  \
# 0                     127037                       5905  ...
# 1                      21838                        896  ...
# 2                         35                          1  ...
# 3                          3                          0  ...
# 4                       7890                        258  ...
#
#    LAMI_RD304_D28_C3_S5_L005  LAMI_RD308_D0_C2_S13_L005  \
# 0                     362236                       1811
# 1                      60647                         27
# 2                         57                          0
# 3                          4                          0
# 4                       4476                          4
#
#    LAMI_RD310_D0_C2_S19_L005  LAMI_RD306_D11_C1_S8_L005  \
# 0                     196880                     825942
# 1                      20516                      65240
# 2                          1                     102859
# 3                          1                     764138
# 4                        661                      94133
#
#    LAMI_RD310_D0_C3_S20_L005  LAMI_RD310_D14_C3_S21_L005  \
# 0                     372845                      441798
# 1                      26311                       13760
# 2                          5                           1
# 3                          0                           0
# 4                        819                         446
#
#    LAMI_RD306_D14_C1_S9_L005  LAMI_RD310_D21_C2_S23_L005  \
# 0                      83571                      196812
# 1                       5157                       28370
# 2                         22                          13
# 3                         25                           0
# 4                      11267                         970
#
#    LAMI_RD308_D14_C3_S16_L005  LAMI_RD304_D0_C1_S1_L005
# 0                      782381                    111499
# 1                        7988                     23177
# 2                           1                        35
# 3                           3                         1
# 4                         635                      2289
#
# [5 rows x 29 columns]

# %%
# Merge gene_info_df with taxa_df on the 'genome' and 'sample_mag' columns to add the 'name' column
gene_info = gene_info.merge(taxa[['sample_mag', 'name']], left_on='genome', right_on='sample_mag', how='left')

# Drop the extra 'sample_mag' column after merging
gene_info.drop(columns=['sample_mag'], inplace=True)

# Add a new column 'sample_name' to gene_info_df
# Extract everything before the 4th underscore and replace underscores with dots
gene_info['sample_name'] = gene_info['scaffold'].str.extract(r'^((?:[^_]*_){3}[^_]*)')[0].str.replace('_', '.', regex=False)

# Merge the 'Zone' column from md into gene_info_df based on 'sample_name'
gene_info = gene_info.merge(md[['sample_name', 'Zone']], on='sample_name', how='left')

# Sort gene_info_df by 'dNdS_substitutions' column in descending order
gene_info = gene_info.sort_values(by='dNdS_substitutions', ascending=False)

# Check dataframe
gene_info.head()
# Out:
#                                                 scaffold  \
# 80975  LAMI_RD306_D28_C3_S12_L005__NODE_3317_length_1...
# 80959  LAMI_RD306_D28_C3_S12_L005__NODE_3317_length_1...
# 80961  LAMI_RD306_D28_C3_S12_L005__NODE_3317_length_1...
# 80962  LAMI_RD306_D28_C3_S12_L005__NODE_3317_length_1...
# 80964  LAMI_RD306_D28_C3_S12_L005__NODE_3317_length_1...
#
#                                                     gene  gene_length  \
# 80975  LAMI_RD306_D28_C3_S12_L005__NODE_3317_length_1...       1746.0
# 80959  LAMI_RD306_D28_C3_S12_L005__NODE_3317_length_1...       1746.0
# 80961  LAMI_RD306_D28_C3_S12_L005__NODE_3317_length_1...       1746.0
# 80962  LAMI_RD306_D28_C3_S12_L005__NODE_3317_length_1...       1746.0
# 80964  LAMI_RD306_D28_C3_S12_L005__NODE_3317_length_1...       1746.0
#
#        coverage   breadth  breadth_minCov  nucl_diversity  start   end  \
# 80975  11.06071  0.936426        0.718786        0.014279      1  1746
# 80959  11.06071  0.936426        0.718786        0.014279      1  1746
# 80961  11.06071  0.936426        0.718786        0.014279      1  1746
# 80962  11.06071  0.936426        0.718786        0.014279      1  1746
# 80964  11.06071  0.936426        0.718786        0.014279      1  1746
#
#        direction  ...  SNV_S_count  SNV_N_count  SNS_count  SNS_S_count  \
# 80975          1  ...         29.0         10.0        7.0          1.0
# 80959          1  ...         29.0         10.0        7.0          1.0
# 80961          1  ...         29.0         10.0        7.0          1.0
# 80962          1  ...         29.0         10.0        7.0          1.0
# 80964          1  ...         29.0         10.0        7.0          1.0
#
#        SNS_N_count  divergent_site_count  \
# 80975          6.0                  46.0
# 80959          6.0                  46.0
# 80961          6.0                  46.0
# 80962          6.0                  46.0
# 80964          6.0                  46.0
#
#                                                   genome         name  \
# 80975  LAMI_RD306_D28_C3_S12_L005__METABAT2__P.1__bin.10  Micrococcus
# 80959  LAMI_RD306_D28_C3_S12_L005__METABAT2__P.1__bin.10  Micrococcus
# 80961  LAMI_RD306_D28_C3_S12_L005__METABAT2__P.1__bin.10  Micrococcus
# 80962  LAMI_RD306_D28_C3_S12_L005__METABAT2__P.1__bin.10  Micrococcus
# 80964  LAMI_RD306_D28_C3_S12_L005__METABAT2__P.1__bin.10  Micrococcus
#
#              sample_name          Zone
# 80975  LAMI.RD306.D28.C3  Non-lesional
# 80959  LAMI.RD306.D28.C3  Non-lesional
# 80961  LAMI.RD306.D28.C3  Non-lesional
# 80962  LAMI.RD306.D28.C3  Non-lesional
# 80964  LAMI.RD306.D28.C3  Non-lesional
#
# [5 rows x 24 columns]

# %%
# Plot Figure

# Define custom color palette for 'Lesional' and 'Non-lesional' zones
palette_zone = {'Lesional': '#FF6347',  # Tomato Red for Lesional
                'Non-lesional': '#7AC9D5'}  # Cornflower Blue for Non-lesional

# Specify the desired order for microbes along the x-axis
microbe_order = ['Cutibacterium acnes', 'Cutibacterium granulosum', 'Lawsonella cleavelandensis', 
                 'Corynebacterium spp.', 'Neisseria spp.', 'Micrococcus', 'Other (combined)']

# Set the figure size
plt.figure(figsize=(12, 6))

# Create a strip plot of dN/dS substitutions by microbe and zone
sns.stripplot(data=gene_info, x='name', y='dNdS_substitutions', hue='Zone', 
              jitter=True, dodge=True, palette=palette_zone, order=microbe_order)

# Set the plot title and axis labels
plt.title('Per Gene dN/dS Ratio of Prokaryotic Species-Level MAGs')  # Main plot title
plt.ylabel('dN/dS Ratio')  # Y-axis label for dN/dS ratios
plt.xlabel('')  # Empty x-axis label as microbe names are already displayed

# Rotate x-axis labels for better readability if names are long
plt.xticks(rotation=45)

# Set legend title to 'Zone' to clarify Lesional vs. Non-lesional grouping
plt.legend(title='Zone', loc='upper left')

# Adjust layout to prevent clipping of labels/titles
plt.tight_layout()

# Save and show the figure
plt.savefig(f'../Figures/metaG_Figures/inStrain/inStrain_dnds_prokaryotic-species.png', dpi=600, bbox_inches='tight', pad_inches=0.1)  # Save as png
plt.savefig(f'../Figures/metaG_Figures/inStrain/inStrain_dnds_prokaryotic-species.svg')  # Save as svg
plt.show()
